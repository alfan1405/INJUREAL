# %%
import os
import hashlib
import shutil

# %%
# !unzip wound_dataset.zip
# Out:
# Archive:  wound_dataset.zip
#    creating: wound_dataset/
#    creating: wound_dataset/Abrasions/
#   inflating: wound_dataset/Abrasions/abrasions (1)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (10)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (11)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (12)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (13)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (14)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (15)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (16)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (17)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (19)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (2)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (20)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (22)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (23)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (24)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (27)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (28)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (29)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (3)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (30)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (31)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (35)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (36)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (37)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (38)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (39)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (4)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (40)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (41)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (42)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (45)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (46)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (47)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (48)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (5)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (50)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (51)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (52)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (53)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (54)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (55)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (57)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (58)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (60)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (63)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (64)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (65)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (66)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (67)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (68)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (69)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (7)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (70)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (71)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (72)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (73)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (74)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (75)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (76)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (77)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (78)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (8)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (80)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (81)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (82)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (83)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (85)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/abrasions (9)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (11)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (12)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (13)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (14)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (16)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (17)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (18)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (19)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (2)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (20)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (22)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (23)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (24)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (25)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (26)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (28)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (29)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (3)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (30)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (33)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (34)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (36)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (37)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (39)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (4)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (40)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (41)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (42)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (44)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (45)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (46)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (47)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (48)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (49)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (5)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (50)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (51)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (53)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (54)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (55)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (57)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (58)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (59)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (6)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (60)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (63)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (64)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (66)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (67)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (69)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (70)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (71)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (72)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (73)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (74)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (77)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (80)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (81)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (82)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (83)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (84)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (85)_resize_only.jpg
#   inflating: wound_dataset/Abrasions/mirrored_abrasions (9)_resize_only.jpg
#    creating: wound_dataset/Bruises/
#   inflating: wound_dataset/Bruises/bruises (1)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (10)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (100)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (101)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (102)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (103)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (104)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (105)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (106)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (108)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (109)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (11)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (110)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (111)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (112)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (115)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (116)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (117)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (118)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (119)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (12)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (13)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (14)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (15)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (16)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (17)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (18)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (19)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (2)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (20)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (23)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (24)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (25)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (26)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (28)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (29)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (3)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (30)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (31)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (32)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (33)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (35)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (36)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (4)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (40)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (41)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (42)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (43)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (44)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (45)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (46)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (47)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (48)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (49)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (5)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (50)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (51)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (52)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (53)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (54)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (55)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (57)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (58)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (59)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (6)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (60)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (62)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (63)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (66)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (67)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (68)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (69)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (70)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (71)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (72)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (73)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (74)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (75)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (76)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (77)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (78)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (79)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (81)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (82)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (83)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (84)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (87)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (88)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (9)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (90)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (92)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (93)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (94)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (95)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (96)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (98)_resize_only.jpg
#   inflating: wound_dataset/Bruises/bruises (99)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (1)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (10)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (100)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (101)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (102)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (103)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (104)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (106)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (107)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (108)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (11)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (110)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (111)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (112)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (113)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (114)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (115)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (117)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (118)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (12)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (121)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (122)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (13)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (14)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (15)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (16)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (17)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (18)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (2)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (20)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (21)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (22)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (24)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (25)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (26)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (27)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (28)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (29)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (3)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (30)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (31)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (33)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (34)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (35)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (36)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (38)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (4)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (41)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (42)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (43)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (44)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (45)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (46)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (47)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (5)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (50)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (51)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (52)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (53)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (54)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (56)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (57)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (58)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (59)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (6)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (60)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (61)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (63)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (65)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (67)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (69)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (7)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (70)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (71)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (73)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (75)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (76)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (77)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (78)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (79)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (8)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (83)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (85)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (88)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (89)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (9)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (90)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (91)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (92)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (93)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (94)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (95)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (96)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (97)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (98)_resize_only.jpg
#   inflating: wound_dataset/Bruises/mirrored_bruises (99)_resize_only.jpg
#    creating: wound_dataset/Burns/
#   inflating: wound_dataset/Burns/burns (1)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (10)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (11)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (12)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (13)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (14)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (15)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (16)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (19)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (2)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (20)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (21)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (22)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (23)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (24)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (27)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (28)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (29)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (3)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (30)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (33)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (34)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (35)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (36)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (37)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (38)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (39)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (4)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (40)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (41)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (43)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (5)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (51)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (53)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (56)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (6)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (7)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (8)_resize_only.jpg
#   inflating: wound_dataset/Burns/burns (9)_resize_only.jpg
#   inflating: wound_dataset/Burns/case1-burns-to-hand-and-arm-1_resize_only.jpg
#   inflating: wound_dataset/Burns/case1-burns-to-hand-and-arm_resize_only.jpg
#   inflating: wound_dataset/Burns/case2-burn-to-arm-2_resize_only.jpg
#   inflating: wound_dataset/Burns/case2-burn-to-arm-6_resize_only.jpg
#   inflating: wound_dataset/Burns/case3-burn-to-head-showing-healing-0_resize_only.jpg
#   inflating: wound_dataset/Burns/case3-burn-to-head-showing-healing-1_resize_only.jpg
#   inflating: wound_dataset/Burns/case3-burn-to-head-showing-healing-3_resize_only.jpg
#   inflating: wound_dataset/Burns/case4-burn-to-leg-treated-with-gel-0_resize_only.jpg
#   inflating: wound_dataset/Burns/case4-burn-to-leg-treated-with-gel-1_resize_only.jpg
#   inflating: wound_dataset/Burns/case4-burn-to-leg-treated-with-gel-2_resize_only.jpg
#   inflating: wound_dataset/Burns/case5-burn-to-foot_resize_only.jpg
#   inflating: wound_dataset/Burns/case6-burn-to-shoulder_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (1)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (10)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (11)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (15)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (16)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (17)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (18)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (19)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (2)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (20)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (21)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (22)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (23)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (25)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (26)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (27)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (28)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (3)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (30)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (31)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (32)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (33)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (34)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (35)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (36)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (37)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (38)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (39)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (4)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (40)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (41)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (43)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (5)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (53)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (54)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (55)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (56)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (6)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (7)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_burns (8)_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_case1-burns-to-hand-and-arm-1_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_case1-burns-to-hand-and-arm_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_case2-burn-to-arm-1_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_case2-burn-to-arm-2_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_case2-burn-to-arm-3_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_case2-burn-to-arm-4_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_case2-burn-to-arm-5_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_case2-burns-to-arm-7_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_case3-burn-to-head-showing-healing-0_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_case3-burn-to-head-showing-healing-2_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_case4-burn-to-leg-treated-with-gel-0_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_case4-burn-to-leg-treated-with-gel-1_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_case4-burn-to-leg-treated-with-gel-2_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_case5-burn-to-foot_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_case6-burn-to-shoulder_resize_only.jpg
#   inflating: wound_dataset/Burns/mirrored_case7-burn-to-thigh_resize_only.jpg

# %%
# --- Data Understanding ---

# Check length of each label
import os
path='/content/wound_dataset'
dataset_dir = os.listdir(path)

total_data = 0 #save total data
for i in dataset_dir:
  label_dir = os.path.join(path, i)
  if os.path.isdir(label_dir):
    files = os.listdir(label_dir)
    num_files = len(files)
    total_data += num_files #add number of data to total_data

    a='{} label has a total of '.format(i).ljust(50)
    a+= ' : '
    print(a, num_files, ' images')
  else:
    print('\nPath {} is not a directory.\n'.format(label_dir))

#after looping is done, print the result
print("\nTotal data across all labels:", total_data)


#Recursively delete all .DS_Store files from the given directory and its subdirectories
def delete_ds_store(path):
  for root, dirs, files in os.walk(path):
    for file in files:
      if file == ".DS_Store":
        os.remove(os.path.join(root, file))
        print(f"Deleted .DS_Store file: {os.path.join(root, file)}")
# Out:
# Burns label has a total of                         :  107  images
# Bruises label has a total of                       :  193  images
# Abrasions label has a total of                     :  131  images
#
# Total data across all labels: 431

# %%
import numpy as np
import cv2
import os
from matplotlib import pyplot as plt
import matplotlib.image as mping
import random
from math import ceil

#create figure
fig = plt.figure(figsize=(10, 10))

#loop through each of the label directories
for i in range(len(dataset_dir)):
    #get the label name
    label_name = dataset_dir[i]

    #create the full path to the label directory
    label_dir = os.path.join(path, label_name)

    #check if the current item in the loop is a directory
    if os.path.isdir(label_dir):
        #open the label directory
        images = os.listdir(label_dir)

        #pick a random image from the directory
        random_image = random.choice(images)

        #create the full path to the random image
        random_image_path = os.path.join(label_dir, random_image)

        #read the image
        img = mping.imread(random_image_path)

        #plot the image
        plt.subplot(ceil(len(dataset_dir)/4), 4, i+1)
        plt.title(label_name)
        plt.imshow(img, cmap='gray')
        plt.axis('off')

#show all plots
plt.tight_layout()
plt.show()

# %%
# --- show image ---
cols = 4
rows = ceil(len(dataset_dir) / cols)

x = 0
for i in dataset_dir:
    label_dir = os.path.join(path, i)

    if os.path.isdir(label_dir):
        files = os.listdir(label_dir)

        # pick random image
        rnd = random.choice(files)

        imgg = os.path.join(label_dir, rnd)
        Image = mping.imread(imgg)

        plt.subplot(cols, rows, x+1)
        plt.imshow(Image)
        plt.title(i)

        plt.axis('off')
        x += 1

    else:
        print("Skipping non-directory file:", label_dir)

# %% [markdown]
# # --- DATA PREPROCESSING ---

# %%
"""Remove duplicate images from each label"""

# !pip install Pillow
import hashlib
from matplotlib.pyplot import imread

import imageio
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

import numpy as np
import shutil

"""Define the functions"""
def find_duplicates(col_name):
    os.chdir(col_name)
    os.getcwd()
    files_list = os.listdir('.')

    print("Number of files in the current directory:", len(files_list))

    duplicates = []
    hash_keys = dict()
    for index, filename in enumerate(os.listdir('.')):
        if os.path.isfile(filename):
            with open(filename, 'rb') as f:
                filehash = hashlib.md5(f.read()).hexdigest()
            if filehash not in hash_keys:

                hash_keys[filehash] = index
            else:
                duplicates.append((index, hash_keys[filehash]))


    if not duplicates:
        print('Result of Duplicates: 0')
    else:
        duplicates.sort(key=lambda x: x[1])
        print('Result of Duplicates:', duplicates)
    return duplicates, files_list
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (11.0.0)

# %%
# Define a function to move files to a new directory
def move_dups_to_new_dir(source_dir, destination_dir, dup_indexes, files_list):
  for index in dup_indexes:
    source_file = files_list[index]
    destination_file = os.path.join(destination_dir, os.path.basename(source_file))
    shutil.move(source_file, destination_file)

# %%
"Checking and Moving The Duplicates"
path='/content/wound_dataset'

duplicate_dir = '/content/DuplicateFiles'

# Loop through all directories in the path
for col_name in os.listdir(path):
  col_path= os.path.join(path, col_name)
  if os.path.isdir(os.path.join(path, col_name)):
    print(f"Checking duplicates in {col_path}")
    result = find_duplicates(col_path)
    if result is not None:
      duplicates, files_list = result
      os.makedirs(duplicate_dir, exist_ok=True) # Create the duplicate directory if it doesn't exist

      # Showing result of duplicates
      for file_indexes in duplicates[:30]:
        try:
          file_index_0, file_index_1 = file_indexes
          if file_index_0 < len(files_list) and file_index_1 < len(files_list):
            plt.subplot(121), plt.imshow(imread(files_list[file_index_1]))
            plt.title('index {}'.format(file_index_1)), plt.xticks([]), plt.yticks([])

            plt.subplot(122), plt.imshow(imread(files_list[file_index_0]))
            plt.title('index {} is the duplicate'.format(file_index_0)), plt.xticks([]), plt.yticks([])

            plt.show()
        except OSError as e:
          continue
# Out:
# Checking duplicates in /content/wound_dataset/Burns
# Number of files in the current directory: 107
# Result of Duplicates: 0
# Checking duplicates in /content/wound_dataset/Bruises
# Number of files in the current directory: 193
# Result of Duplicates: 0
# Checking duplicates in /content/wound_dataset/Abrasions
# Number of files in the current directory: 131
# Result of Duplicates: 0

# %%
"""SMOTE for imbalanced dataset"""
import pandas as pd
from skimage.transform import resize
from skimage.io import imread
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from collections import Counter

Categories_1 = os.listdir(path)

flat_data_arr_1 = []
target_arr_1 = []
for i in Categories_1:

    print(f'loading... category: {i}')
    path1 = os.path.join(path, i)
    for img in os.listdir(path1):
        if img != '.DS_Store':
            img_array = imread(os.path.join(path1, img))
            img_resized = resize(img_array, (150, 150, 3))
            flat_data_arr_1.append(img_resized.flatten())
            target_arr_1.append(Categories_1.index(i))
    print(f'loaded category: {i} successfully')

flat_data_1 = np.array(flat_data_arr_1)
target = np.array(target_arr_1)

df_1 = pd.DataFrame(flat_data_1)
df_1['Target'] = target

x_1 = df_1.iloc[:, :-1]
y_1 = df_1.iloc[:, -1]

y_1 = LabelEncoder().fit_transform(y_1)

# Terapkan SMOTE
smote = SMOTE()
x_smote, y_smote = smote.fit_resample(x_1, y_1)

# Cek jumlah data sebelum dan sesudah SMOTE
print("Sebelum SMOTE:", Counter(y_1))
print("Setelah SMOTE:", Counter(y_smote))
# Out:
# loading... category: Burns
# loaded category: Burns successfully
# loading... category: Bruises
# loaded category: Bruises successfully
# loading... category: Abrasions
# loaded category: Abrasions successfully
# Sebelum SMOTE: Counter({1: 193, 2: 131, 0: 107})
# Setelah SMOTE: Counter({0: 193, 1: 193, 2: 193})

# %% [markdown]
# # OVERSAMPLING

# %%
# --- Oversampling Methode ---
from imblearn.over_sampling import SMOTE
from collections import Counter

oversample_1 = SMOTE()
x_1, y_1 = oversample_1.fit_resample(x_1, y_1)

# summarize the new class distribution
counter = Counter(y_1)
print(counter)
# Out:
# Counter({0: 193, 1: 193, 2: 193})

# %%
# --- Transforming into pictures again ---
# Create new dir for dataset after being resampled
import os
from PIL import Image
import numpy as np

new_dir = '/content/new_dataset_after_resampling'
os.makedirs(new_dir, exist_ok=True)  # Use makedirs with exist_ok to avoid errors if directory exists

for i in range(len(x_1)):  # Loop through the indices of x_1
    # Check if directory exists and create it if needed
    if not os.path.isdir(os.path.join(new_dir, Categories_1[y_1[i]])):
        os.makedirs(os.path.join(new_dir, Categories_1[y_1[i]]), exist_ok=True)

    # Define image name and path
    name_dir = os.path.join(new_dir, Categories_1[y_1[i]])
    a = np.array(x_1.iloc[i]).reshape(150, 150, 3)
    img = Image.fromarray((a * 255).astype(np.uint8))
    img.save(os.path.join(name_dir, Categories_1[y_1[i]] + '_{}.png'.format(i)))

# %%
# --- Menghitung jumlah data ---
dataset_dir = os.listdir(new_dir)
total_data = 0  # Inisialisasi variabel untuk menyimpan total data

for label in dataset_dir:  # Iterate through label directory names
    label_dir = os.path.join(new_dir, label)
    if os.path.isdir(label_dir):
        files = os.listdir(label_dir)
        num_files = len(files)
        total_data += num_files  # Add the number of label data to total_data

        a = '{} label has a total of '.format(label).ljust(50)
        a += ': '
        print(a, num_files, 'images')
    else:
        print('\nPath {} is not a directory.\n'.format(label_dir))

# After the loop is finished, print the total overall data
print("\nTotal data across all labels:", total_data)
# Out:
# Burns label has a total of                        :  193 images
# Bruises label has a total of                      :  193 images
# Abrasions label has a total of                    :  193 images
#
# Total data across all labels: 579

# %% [markdown]
# # AUGMENTASI

# %%
# --- Augmentation Data ---
# !pip install split-folders
import splitfolders
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
# --- Augmentation Parameters ---
BATCH_SIZE = 16
TARGET_SIZE = 150
AUGMENTATION_FACTOR = 8  # Number of augmentations

dataset_dir = '/content/new_dataset_after_resampling'
output_dir = '/content/Dataset_split'

# %%
# --- Splitting Dataset ---
splitfolders.ratio(dataset_dir, output=output_dir, seed=42,
                   ratio=(0.8, 0.2), group_prefix=None)

train_dir = '/content/Dataset_split/train'
val_dir = '/content/Dataset_split/val'
# Out:
# Copying files: 579 files [00:00, 4932.74 files/s]

# %%
# --- Create new dir for final augmented dataset ---
augmented_train_dir = '/content/Dataset_split/train_augmented'
os.makedirs(augmented_train_dir, exist_ok=True)

# --- Create subdir in augmented_train_dir (for classes) ---
class_names = os.listdir(dataset_dir)

for class_name in class_names:
    class_augmented_dir = os.path.join(augmented_train_dir, class_name)
    os.makedirs(class_augmented_dir, exist_ok=True)

# --- Calling classes function ---
def get_class_name_from_image(image_path):
    """
    Ambil nama direktori terakhir dari path gambar sebagai nama kelas
    """
    class_name = os.path.basename(os.path.dirname(image_path))
    return class_name

# --- Inisialitation Augmentation Generator ---
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.4,
    zoom_range=0.4,
    rotation_range=40,
    horizontal_flip=True,
    fill_mode='nearest',
)

val_datagen = ImageDataGenerator(
    rescale=1./255,
)

# %%
# --- Augmentation Process ---
for root, _, files in os.walk(train_dir):
    for file in files:
        image_path = os.path.join(root, file)
        img = tf.keras.preprocessing.image.load_img(image_path, target_size=(TARGET_SIZE, TARGET_SIZE))
        x = tf.keras.preprocessing.image.img_to_array(img)
        x = x.reshape((1,) + x.shape)

        i = 0
        class_name = get_class_name_from_image(image_path)
        class_augmented_dir = os.path.join(augmented_train_dir, class_name)
        os.makedirs(class_augmented_dir, exist_ok=True)
        for batch in train_datagen.flow(x, batch_size=1):
            augmented_image = tf.keras.preprocessing.image.array_to_img(batch[0])
            augmented_image.save(os.path.join(class_augmented_dir, f'augmented_{i}.png'))
            i += 1
            if i >= AUGMENTATION_FACTOR:
                break

# %%
"""Evaluation of The Augmentation Results"""
# Checking PSNR
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage import io, color

import shutil

# Dir inisialitation
original_images_dir = "/content/Dataset_split/train"
augmented_images_dir = "/content/Dataset_split/train_augmented"
output_dir = "/content/resoluted_dataset"  # output dir to save imgs

os.makedirs(output_dir, exist_ok=True)

# %%
# Looping each subdir classes
class_names = os.listdir(augmented_images_dir)  # Use train_augmented dir
for class_name in class_names:
    class_original_dir = os.path.join(original_images_dir, class_name)
    class_augmented_dir = os.path.join(augmented_images_dir, class_name)

    # Variables inisialitation for current class
    total_psnr = 0
    count = 0

    original_images = os.listdir(class_original_dir)

    # Looping imgs in class subdir
    for image_name in original_images:
        original_image_path = os.path.join(class_original_dir, image_name)
        original_image = io.imread(original_image_path)

        # Making sure the images are in grayscale mode
        original_image = color.rgb2gray(original_image)

# %%
for augmented_image_name in os.listdir(class_augmented_dir):
    augmented_image_path = os.path.join(class_augmented_dir, augmented_image_name)
    augmented_image = io.imread(augmented_image_path)

    # Making sure the images are in grayscale mode
    augmented_image = color.rgb2gray(augmented_image)

    # psnr score
    psnr_score = psnr(original_image, augmented_image)

    # If PSNR score > 11..., copy the imgs to resolute_dataset
    if psnr_score > 11.992841544610027:
        target_dir = os.path.join(output_dir, class_name)
        os.makedirs(target_dir, exist_ok=True)
        shutil.copy(augmented_image_path, target_dir)

    total_psnr += psnr_score
    count += 1

# %%
# Calculating PSNR means for current class
average_psnr = total_psnr / count

# Tampilkan rata-rata PSNR untuk kelas saat ini
print(f"Class: {class_name}, Average PSNR Score: {average_psnr}")

train_final = '/content/Dataset_split/train_augmented'
# Out:
# Class: Abrasions, Average PSNR Score: 20.667344662490805

# %%
# Generator for augmented dataset
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_generator = train_datagen.flow_from_directory(
    train_final,
    target_size=(TARGET_SIZE, TARGET_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(TARGET_SIZE,TARGET_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
)
# Out:
# Found 462 images belonging to 3 classes.
# Found 117 images belonging to 3 classes.

# %%
"Checking Data After Augmented"
# Checking the length of resoluted_dataset_dir
resoluted_dataset_dir = "/content/resoluted_dataset"

# Dictionary inisialitation to save data of each class
class_counts = {}

# %%
# --- Checking Data After Augmented ---
# Looping through each subdir
class_names = os.listdir(resoluted_dataset_dir)

total_data = 0
# Class_counts = {}  # Inisialisasi dictionary untuk menyimpan total data

for class_name in class_names:
    class_dir = os.path.join(resoluted_dataset_dir, class_name)
    class_count = len(os.listdir(class_dir))  # Menghitung jumlah data
    class_counts[class_name] = class_count  # Menyimpan jumlah data ke dictionary

    total_data += class_count  # Menambahkan jumlah data ke total_data

# Menampilkan jumlah data di setiap kelas
for class_name, count in class_counts.items():
    print(f"Class: {class_name}, Count: {count}")

# Menampilkan jumlah total data
print("Total Data:", total_data)

"Result of Augmentations"
result = sorted(os.listdir(train_final))

plt.figure(figsize=(12, 12))

for i, class_name in enumerate(result):
    class_augmented_dir = os.path.join(train_final, class_name)
    files = os.listdir(class_augmented_dir)  # Mengambil satu gambar hasil augmentasi dari setiap kelas

    if files:
        image_path = os.path.join(class_augmented_dir, files[0])
        img = tf.keras.preprocessing.image.load_img(image_path)
        plt.subplot(4, 4, i + 1)  # Mengatur tata letak subplot
        plt.imshow(img)
        plt.title(class_name)
        plt.axis("off")

plt.show()
# Out:
# Class: Burns, Count: 8
# Class: Bruises, Count: 8
# Class: Abrasions, Count: 8
# Total Data: 24

# %% [markdown]
# ## **MODELLING**

# %%
"""Build CNN"""
# VGG16
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Input # Import the Input layer

model_vgg = tf.keras.models.Sequential([
    VGG16(weights="imagenet", include_top=False,
          input_tensor=Input(shape=(TARGET_SIZE, TARGET_SIZE, 3))),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(3, activation='softmax')  # 3 kelas
])

model_vgg.layers[0].trainable = False

model_vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)                   │ (None, 4, 4, 512)           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       1,048,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,763,779 (60.13 MB)
#  Trainable params: 1,049,091 (4.00 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
tf.keras.utils.plot_model(model_vgg)

# %%
# --- VGG-16 ---
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

lr_reduce = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.6,
    patience=6,
    verbose=1,
    mode='min',
    min_lr=5e-5
)

callbacks = EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=10,
    restore_best_weights=True
)

train_steps = train_generator.samples
val_steps = val_generator.samples
epoch = 100

model_vgg.compile(optimizer=tf.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model_vgg.fit(
    train_generator,
    steps_per_epoch=train_steps // BATCH_SIZE,
    epochs=epoch,
    validation_data=val_generator,
    validation_steps=val_steps // BATCH_SIZE,
    callbacks=[lr_reduce, callbacks],
    verbose=1
)

# --- Showing best results ---
best_val_accuracy = max(history.history['val_accuracy'])
best_val_loss = min(history.history['val_loss'])

best_train_accuracy = max(history.history['accuracy'])
best_train_loss = min(history.history['loss'])

print(f"Best val_acc: {best_val_accuracy:.4f}")
print(f"Best val_loss: {best_val_loss:.4f}")
print(f"Best train_acc: {best_train_accuracy:.4f}")
print(f"Best train_loss: {best_train_loss:.4f}")
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 175s 6s/step - accuracy: 0.4292 - loss: 1.4183 - val_accuracy: 0.6696 - val_loss: 0.8131 - learning_rate: 0.0010
# Epoch 2/100
#  1/28 ━━━━━━━━━━━━━━━━━━━━ 1:39 4s/step - accuracy: 0.5000 - loss: 1.0938
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.5000 - loss: 1.0938 - val_accuracy: 0.6000 - val_loss: 0.9094 - learning_rate: 0.0010
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 180s 5s/step - accuracy: 0.6107 - loss: 0.8490 - val_accuracy: 0.7321 - val_loss: 0.7016 - learning_rate: 0.0010
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 272ms/step - accuracy: 0.3750 - loss: 1.2087 - val_accuracy: 1.0000 - val_loss: 0.3695 - learning_rate: 0.0010
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.6273 - loss: 0.7981 - val_accuracy: 0.7232 - val_loss: 0.6179 - learning_rate: 0.0010
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 254ms/step - accuracy: 0.6875 - loss: 0.8765 - val_accuracy: 0.8000 - val_loss: 0.5382 - learning_rate: 0.0010
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 191s 5s/step - accuracy: 0.6476 - loss: 0.7554 - val_accuracy: 0.8036 - val_loss: 0.5485 - learning_rate: 0.0010
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 243ms/step - accuracy: 0.6250 - loss: 0.8842 - val_accuracy: 0.8000 - val_loss: 0.3729 - learning_rate: 0.0010
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.7702 - loss: 0.6088 - val_accuracy: 0.8571 - val_loss: 0.4554 - learning_rate: 0.0010
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 255ms/step - accuracy: 0.8750 - loss: 0.4622 - val_accuracy: 0.8000 - val_loss: 0.2986 - learning_rate: 0.0010
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 190s 5s/step - accuracy: 0.7221 - loss: 0.6406 - val_accuracy: 0.8661 - val_loss: 0.4531 - learning_rate: 0.0010
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.8125 - loss: 0.6756 - val_accuracy: 1.0000 - val_loss: 0.2937 - learning_rate: 0.0010
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 195s 5s/step - accuracy: 0.7626 - loss: 0.5888 - val_accuracy: 0.8125 - val_loss: 0.4240 - learning_rate: 0.0010
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.6875 - loss: 0.7445 - val_accuracy: 1.0000 - val_loss: 0.2701 - learning_rate: 0.0010
# Best val_acc: 1.0000
# Best val_loss: 0.2701
# Best train_acc: 0.8750
# Best train_loss: 0.4622

# %%
from sklearn.metrics import confusion_matrix, classification_report
Y_pred = model_vgg.predict(val_generator, val_steps // BATCH_SIZE+1)
y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')
cf_mtx = confusion_matrix(val_generator.classes, y_pred)
print(cf_mtx)

print('Classification Report')
target_names = list(train_generator.class_indices.keys())
print(classification_report(val_generator.classes, y_pred, target_names=target_names))
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 4s/step
# Confusion Matrix
# [[26  6  7]
#  [ 2 31  6]
#  [ 2  5 32]]
# Classification Report
#               precision    recall  f1-score   support
#
#    Abrasions       0.87      0.67      0.75        39
#      Bruises       0.74      0.79      0.77        39
#        Burns       0.71      0.82      0.76        39
#
#     accuracy                           0.76       117
#    macro avg       0.77      0.76      0.76       117
# weighted avg       0.77      0.76      0.76       117

# %% [markdown]
# # Plot False Detection

# %%
# Number of classes with errors to display
classes_with_errors_num = 5

# Sizing
img_ns = (150, 150)  # Define image size here

# Plotting
plt.figure(figsize=(20, 4))

class_indices_with_errors = []  # List to store class indices with errors

# Find all incorrect indices.
incorrect_indices = np.where(val_generator.classes != y_pred)[0]

# Loop through each class
for class_ind in range(len(target_names)):
    # Filter incorrect indices for the current class
    incorrect_indices_for_class = np.intersect1d(
        np.where(val_generator.classes == class_ind),
        incorrect_indices
    )

    if len(incorrect_indices_for_class) > 0:
        class_indices_with_errors.append(class_ind)

# Loop through classes with errors
for i in range(min(classes_with_errors_num, len(class_indices_with_errors))):
    class_ind = class_indices_with_errors[i]

    # Filter incorrect indices for the current class
    incorrect_indices_for_class = np.intersect1d(
        np.where(val_generator.classes == class_ind),
        incorrect_indices
    )

    index = incorrect_indices_for_class[0]  # Select the first error for this class

    true_class = val_generator.classes[index]
    predicted_class = y_pred[index]

    # Loading incorrect prediction images using PIL
    img_path = val_generator.filepaths[index]
    img = Image.open(img_path)

    # Sizing
    img = img.resize(img_ns)

    # Subplotting
    plt.subplot(1, classes_with_errors_num, i + 1)
    plt.imshow(img)

    plt.title(f"True: {target_names[true_class]}\nPredicted: {target_names[predicted_class]}", fontsize=10)
    plt.axis('off')

# Showing results
plt.show()

# %% [markdown]
# # Creating DataFrame and Heatmap

# %%
import seaborn as sns
import pandas as pd

cm_df = pd.DataFrame(cf_mtx, index=target_names, columns=target_names)
plt.figure(figsize=(10, 15))

# Using axis orientation
sns.heatmap(cm_df, annot=True, cmap='CMRmap', fmt='d', cbar=False,
            square=True,
            xticklabels=target_names, yticklabels=target_names)
plt.title('Confusion Matrix')

plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')

plt.xticks(rotation=45)
plt.yticks(rotation=0)

plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(15, 10))

plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')

plt.grid()
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.title('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')

plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.grid()
plt.title('Loss')
plt.xlabel('epoch')

plt.show()

# %%
model_vgg.save('/content/model_VGG16.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model_vgg)
tflite_model = converter.convert()

with tf.io.gfile.GFile('/content/model_VGG16.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpj0tdrhg2'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name='keras_tensor_19')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   133257204135040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257203578512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257189844320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257189836752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257189844672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257187873136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257187880000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257187872080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257187884224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257187881232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257187884752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257187880176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257187872960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257186890624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257186894848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257186891680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257186897664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257186893792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257186900480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257186896608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257186901536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257186893616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257186898896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257186650320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257186647504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257186651376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257186640816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257182116528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257182117232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133257182113712: TensorSpec(shape=(), dtype=tf.resource, name=None)
